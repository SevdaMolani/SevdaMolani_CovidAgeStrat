# %% [markdown]
# _Author_ = "Sevda Molani"
#
# _copyright_ = "2022 Sevda Molani"
#
# _License_ = "Institute for Systems Biology"
#
# _Version_ = "1.0"

# %%
from pyspark.sql.types import *
from pyspark.sql.functions import *
import numpy as np

# %%
df1 = spark.sql("""SELECT 
CONCAT(instance, pat_id) as patient_id,
pat_id,
instance,
pat_enc_csn_id
FROM 
rdp_phi_sandbox.sm_positive_delta_results_feb""")

# %%
### Max_who_1
tmp_1 = spark.sql(
"""
SELECT pat_id, instance,pat_enc_csn_id, admissiondatetime,onehourbase, max_who_1
FROM (
SELECT sm_positive_delta_results_feb.pat_id, sm_positive_delta_results_feb.instance,sm_positive_delta_results_feb.pat_enc_csn_id,instance, admissiondatetime,onehourbase, MAX(rdp_phi_sandbox. sm_who_scores_feb.who_score) as max_who_1
FROM rdp_phi_sandbox.sm_who_scores_feb
INNER JOIN rdp_phi_sandbox.sm_positive_delta_results_feb ON sm_who_scores_feb.patient_id = sm_positive_delta_results_feb.patient_id
WHERE TIMESTAMP(rdp_phi_sandbox.sm_who_scores_feb.record_dt) <= onehourbase + INTERVAL '1' day
AND TIMESTAMP(rdp_phi_sandbox.sm_who_scores_feb.record_dt) >= onehourbase
GROUP BY sm_positive_delta_results_feb.pat_id, sm_positive_delta_results_feb.instance, sm_positive_delta_results_feb.pat_enc_csn_id,admissiondatetime,onehourbase)
"""
)
tmp_1= tmp_1.dropDuplicates()
tmp_1.createOrReplaceTempView('tmp_1')

### Max_who_7
tmp_7 = spark.sql(
"""
SELECT pat_id,instance, pat_enc_csn_id, admissiondatetime,onehourbase, max_who_7
FROM (
SELECT sm_positive_delta_results_feb.pat_id, sm_positive_delta_results_feb.instance,sm_positive_delta_results_feb.pat_enc_csn_id, admissiondatetime,onehourbase, MAX(rdp_phi_sandbox.sm_who_scores_feb.who_score) as max_who_7
FROM rdp_phi_sandbox.sm_who_scores_feb
INNER JOIN rdp_phi_sandbox.sm_positive_delta_results_feb ON rdp_phi_sandbox.sm_who_scores_feb.patient_id = sm_positive_delta_results_feb.patient_id
WHERE TIMESTAMP(rdp_phi_sandbox.sm_who_scores_feb.record_dt) <= onehourbase + INTERVAL '7' day
AND TIMESTAMP(rdp_phi_sandbox.sm_who_scores_feb.record_dt) >= onehourbase
GROUP BY sm_positive_delta_results_feb.pat_id, sm_positive_delta_results_feb.instance, sm_positive_delta_results_feb.pat_enc_csn_id,admissiondatetime,onehourbase)
"""
)
tmp_7= tmp_7.dropDuplicates()
tmp_7.createOrReplaceTempView('tmp_7')

### Max_who_14
tmp_14 = spark.sql(
"""
SELECT pat_id,instance, pat_enc_csn_id, admissiondatetime,onehourbase, max_who_14
FROM (
SELECT sm_positive_delta_results_feb.pat_id, sm_positive_delta_results_feb.instance,sm_positive_delta_results_feb.pat_enc_csn_id, admissiondatetime,onehourbase, MAX(rdp_phi_sandbox.sm_who_scores_feb.who_score) as max_who_14
FROM rdp_phi_sandbox.sm_who_scores_feb
INNER JOIN rdp_phi_sandbox.sm_positive_delta_results_feb ON rdp_phi_sandbox.sm_who_scores_feb.patient_id = sm_positive_delta_results_feb.patient_id
WHERE TIMESTAMP(rdp_phi_sandbox.sm_who_scores_feb.record_dt) <= onehourbase + INTERVAL '14' day
AND TIMESTAMP(rdp_phi_sandbox.sm_who_scores_feb.record_dt) >= onehourbase
GROUP BY sm_positive_delta_results_feb.pat_id, sm_positive_delta_results_feb.instance, sm_positive_delta_results_feb.pat_enc_csn_id,admissiondatetime,onehourbase)
"""
)
tmp_14= tmp_14.dropDuplicates()
tmp_14.createOrReplaceTempView('tmp_14')

### Max_who_28
tmp_28 = spark.sql(
"""
SELECT pat_id,instance, pat_enc_csn_id, admissiondatetime,onehourbase, max_who_28
FROM (
SELECT sm_positive_delta_results_feb.pat_id, sm_positive_delta_results_feb.instance,sm_positive_delta_results_feb.pat_enc_csn_id, admissiondatetime,onehourbase, MAX(rdp_phi_sandbox.sm_who_scores_feb.who_score) as max_who_28
FROM rdp_phi_sandbox.sm_who_scores_feb
INNER JOIN rdp_phi_sandbox.sm_positive_delta_results_feb ON rdp_phi_sandbox.sm_who_scores_feb.patient_id = sm_positive_delta_results_feb.patient_id
WHERE TIMESTAMP(rdp_phi_sandbox.sm_who_scores_feb.record_dt) <= onehourbase + INTERVAL '28' day
AND TIMESTAMP(rdp_phi_sandbox.sm_who_scores_feb.record_dt) >= onehourbase
GROUP BY sm_positive_delta_results_feb.pat_id, sm_positive_delta_results_feb.instance, sm_positive_delta_results_feb.pat_enc_csn_id,admissiondatetime,onehourbase)
"""
)
tmp_28= tmp_28.dropDuplicates()
tmp_28.createOrReplaceTempView('tmp_28')

### Max_who_56
tmp_56 = spark.sql(
"""
SELECT pat_id,instance, pat_enc_csn_id, admissiondatetime,onehourbase, max_who_56
FROM (
SELECT sm_positive_delta_results_feb.pat_id, sm_positive_delta_results_feb.instance,sm_positive_delta_results_feb.pat_enc_csn_id, admissiondatetime,onehourbase, MAX(rdp_phi_sandbox.sm_who_scores_feb.who_score) as max_who_56
FROM rdp_phi_sandbox.sm_who_scores_feb
INNER JOIN rdp_phi_sandbox.sm_positive_delta_results_feb ON rdp_phi_sandbox.sm_who_scores_feb.patient_id = sm_positive_delta_results_feb.patient_id
WHERE TIMESTAMP(rdp_phi_sandbox.sm_who_scores_feb.record_dt) <= onehourbase + INTERVAL '56' day
AND TIMESTAMP(rdp_phi_sandbox.sm_who_scores_feb.record_dt) >= onehourbase
GROUP BY sm_positive_delta_results_feb.pat_id, sm_positive_delta_results_feb.instance, sm_positive_delta_results_feb.pat_enc_csn_id,admissiondatetime,onehourbase)
"""
)
tmp_56= tmp_56.dropDuplicates()
tmp_56.createOrReplaceTempView('tmp_56')

#tmp1.createOrReplaceTempView('tmp1')
d1 = tmp_56.join(tmp_28, ['pat_id', 'pat_enc_csn_id','instance',"admissiondatetime","onehourbase"],"inner")
d2 = d1.join(tmp_14, ['pat_id', 'pat_enc_csn_id','instance',"admissiondatetime","onehourbase"],"inner")
d3 = d2.join(tmp_7, ['pat_id', 'pat_enc_csn_id','instance',"admissiondatetime","onehourbase"],"inner")
d4 = d3.join(tmp_1, ['pat_id', 'pat_enc_csn_id','instance',"admissiondatetime","onehourbase"],"inner")
d4 = d4.withColumn('patient_id', concat('instance', 'pat_id'))
d4=d4.dropDuplicates()
d4.createOrReplaceTempView('d4')

#######################################JOINING the Tables

### first_Who_date
tmp2 = spark.sql(
"""
SELECT patient_id,pat_id,instance,pat_enc_csn_id, admissiondatetime,onehourbase, max_who_1, max_who_7, max_who_14, max_who_28, max_who_56,first_who_date
FROM (
SELECT d4.patient_id,d4.pat_id, d4.pat_enc_csn_id, d4.instance, admissiondatetime,onehourbase,max_who_1, max_who_7, max_who_14, max_who_28, max_who_56, MIN(TIMESTAMP(rdp_phi_sandbox.sm_who_scores_feb.record_dt)) as first_who_date
FROM rdp_phi_sandbox.sm_who_scores_feb
INNER JOIN d4 ON rdp_phi_sandbox.sm_who_scores_feb.patient_id = d4.patient_id
WHERE TIMESTAMP(rdp_phi_sandbox.sm_who_scores_feb.record_dt) >= onehourbase - INTERVAL '24' hour
AND TIMESTAMP(rdp_phi_sandbox.sm_who_scores_feb.record_dt) <= onehourbase + INTERVAL '1' hour
AND rdp_phi_sandbox.sm_who_scores_feb.who_score IS NOT NULL
GROUP BY d4.patient_id,d4.pat_id,d4.instance, d4.pat_enc_csn_id,admissiondatetime,onehourbase, max_who_1, max_who_7, max_who_14, max_who_28, max_who_56)
"""
)
tmp2= tmp2.dropDuplicates()
tmp2.createOrReplaceTempView('tmp2')

### First Who 
tmp3 = spark.sql(
"""
SELECT pat_id,instance, pat_enc_csn_id, admissiondatetime,onehourbase, max_who_1, max_who_7, max_who_14, max_who_28, max_who_56, first_who_date, first_who
FROM (
SELECT tmp2.pat_id,tmp2.instance, tmp2.pat_enc_csn_id, admissiondatetime,onehourbase, max_who_1, max_who_7, max_who_14, max_who_28, max_who_56, first_who_date, MIN(rdp_phi_sandbox.sm_who_scores_feb.who_score) as first_who
FROM rdp_phi_sandbox.sm_who_scores_feb
INNER JOIN tmp2 ON rdp_phi_sandbox.sm_who_scores_feb.patient_id = tmp2.patient_id
WHERE TIMESTAMP(rdp_phi_sandbox.sm_who_scores_feb.record_dt) == first_who_date
GROUP BY tmp2.pat_id,tmp2.instance, tmp2.pat_enc_csn_id,admissiondatetime,onehourbase,max_who_1, max_who_7, max_who_14, max_who_28, max_who_56,first_who_date)
"""
)
tmp3= tmp3.dropDuplicates()
df = df1.join(tmp3, ['pat_id', 'pat_enc_csn_id','instance'],'left')

df= df.dropDuplicates()

# %%
def get_all_descendant_snomed_codes(code):
  descendant_snomed_codes_df = spark.sql(
  """
  SELECT
    oc1.concept_code as ancestor_snomed_code,
    oc1.concept_name as ancestor_concept_name,
    oc2.concept_code as descendant_snomed_code,
    oc2.concept_name as descendant_concept_name
  FROM (
    SELECT * FROM rdp_phi_sandbox.omop_concept_2020_08_05
    WHERE
      concept_code = {snomed_code} AND
      vocabulary_id = 'SNOMED') as oc1
  JOIN rdp_phi_sandbox.omop_concept_ancestor_2020_08_05 as oca
  ON oc1.concept_id = oca.ancestor_concept_id
  JOIN rdp_phi_sandbox.omop_concept_2020_08_05 as oc2
  ON oca.descendant_concept_id = oc2.concept_id
  ORDER BY min_levels_of_separation, oc2.concept_name
  """.format(snomed_code=code))
  
  return descendant_snomed_codes_df


def get_dsi_from_snomed_descendant(code):
  query = "SELECT * FROM rdp_phi_sandbox.jl_diagnosis_snomed_icd" 
  df_dsi = spark.sql(query)
  
  df_snomed = get_all_descendant_snomed_codes(code)
  df_snomed = df_snomed.select('descendant_snomed_code')
  
  df = df_dsi.join(df_snomed, df_dsi.SNOMED == df_snomed.descendant_snomed_code, 
                   how='inner').drop(df_snomed.descendant_snomed_code).drop(df_dsi.name)
  
  return df

# %%
### Reviewed codes - these are reviewed codes, including the additional GI factors

rf2snomed = {} # dictionary for mapping the risk factor names to their snomed codes

rf2snomed['htn'] = ['31992008', #Secondary
                    '59621000', #Essential
                   ] 

rf2snomed['asthma'] = ['195967001'] 

rf2snomed['COPD'] = [
  '13645005', # Chronic obstructive lung disease (disorder)
  '87433001', # Emphysema (disorder)
  '185086009', # Chronic bronchitis
]

rf2snomed['stroke'] = ['230690007']

rf2snomed['liver_disease'] = ['235856003']

rf2snomed['ckd'] = ['709044004'] 

rf2snomed['hld'] = ['55822004','370992007'] #hyperlipidemia and dyslipidemia

rf2snomed['osa'] = ['78275009'] 

rf2snomed['diabetes'] = ['44054006', #type 2
                         '46635009' #type 1 
                        ]

rf2snomed['sot'] = ['739024006', #heart
                    '739025007', #cild of hear and is heart-lung
                    '737295003', #kidney
                    '737297006', #liver
                    '737296002' #lung
                   ] # Solid organ transplantation

rf2snomed['ics'] = ['737300001', #bone marrow
                    '370388006', #immunocompromised
                    '370391006', #immunosuppressed
                    '234532001', #Immunodeficiency disorder
                    '86406008', #HIV
                    '62479008' #Acquired immune deficiency syndrome
                   ] # Immunocompromised state

rf2snomed['dementia'] = ['52448006'] #active

#rf2snomed['heart_conditions'] = ['53741008', '84114007', '85898001'] 
rf2snomed['Coronary_arteriosclerosis'] =['53741008','443502000'] #active
rf2snomed['Heart_failure'] =['84114007'] #active
rf2snomed['Cardiomyopathy'] =['85898001'] #active

print(len(rf2snomed))

# %%
def add_risk_factors(df, risk_factors_dict):
  for risk_factor in risk_factors_dict:
    codes = risk_factors_dict[risk_factor]
    diagnosis_id_list = []
    for code in codes:
      df_dsi = get_dsi_from_snomed_descendant(code)
      new_diag_id = [str(int(row.id)) for row in df_dsi.select('id').distinct().collect()]
      diagnosis_id_list = diagnosis_id_list + new_diag_id
    diagnosis_ids = "','".join(diagnosis_id_list)
    
    tmp =  spark.sql(
    """
    SELECT DISTINCT sm_positive_delta_results_feb.pat_id,sm_positive_delta_results_feb.instance, sm_positive_delta_results_feb.pat_enc_csn_id, IF(COUNT(diagnosis.dx_id) > 0, 'yes', 'no') AS """ + risk_factor + """ 
    FROM (((rdp_phi.problemlist
      INNER JOIN rdp_phi.diagnosismapping ON rdp_phi.problemlist.dx_id = rdp_phi.diagnosismapping.dx_id)
      INNER JOIN rdp_phi.diagnosis ON rdp_phi.diagnosismapping.dx_id = rdp_phi.diagnosis.dx_id)
      INNER JOIN rdp_phi_sandbox.sm_positive_delta_results_feb ON problemlist.pat_id = sm_positive_delta_results_feb.pat_id AND problemlist.instance = sm_positive_delta_results_feb.instance)
    WHERE problemlist.NOTED_DATE + INTERVAL 1 day < sm_positive_delta_results_feb.onehourbase 
      AND diagnosismapping.dx_id in ('""" + diagnosis_ids + """')
      AND (problemlist.problemstatus = "Active" OR problemlist.NOTED_DATE >= sm_positive_delta_results_feb.onehourbase - INTERVAL 730 day)
    GROUP BY sm_positive_delta_results_feb.pat_id,sm_positive_delta_results_feb.instance, sm_positive_delta_results_feb.pat_enc_csn_id
    """
    )
    
    print(risk_factor)
    df = df.join(tmp, ['pat_id', 'pat_enc_csn_id','instance'], how='left').fillna({risk_factor: 'no'})
  return df

# %%
df = add_risk_factors(df, rf2snomed)

# %%
rf2snomed = {} # dictionary for mapping the risk factor names to their snomed codes

rf2snomed['cancer'] = ['363346000'] # any kind of malignancy #active

print(len(rf2snomed))

# %%
def add_risk_factors(df, risk_factors_dict):
  for risk_factor in risk_factors_dict:
    codes = risk_factors_dict[risk_factor]
    diagnosis_id_list = []
    for code in codes:
      df_dsi = get_dsi_from_snomed_descendant(code)
      new_diag_id = [str(int(row.id)) for row in df_dsi.select('id').distinct().collect()]
      diagnosis_id_list = diagnosis_id_list + new_diag_id
    diagnosis_ids = "','".join(diagnosis_id_list)
    
    tmp =  spark.sql(
    """
    SELECT DISTINCT sm_positive_delta_results_feb.pat_id,sm_positive_delta_results_feb.instance, sm_positive_delta_results_feb.pat_enc_csn_id, IF(COUNT(diagnosis.dx_id) > 0, 'yes', 'no') AS """ + risk_factor + """ 
    FROM (((rdp_phi.problemlist
      INNER JOIN rdp_phi.diagnosismapping ON rdp_phi.problemlist.dx_id = rdp_phi.diagnosismapping.dx_id)
      INNER JOIN rdp_phi.diagnosis ON rdp_phi.diagnosismapping.dx_id = rdp_phi.diagnosis.dx_id)
      INNER JOIN rdp_phi_sandbox.sm_positive_delta_results_feb ON problemlist.pat_id = sm_positive_delta_results_feb.pat_id AND problemlist.instance = sm_positive_delta_results_feb.instance)
    WHERE problemlist.NOTED_DATE + INTERVAL 1 day < sm_positive_delta_results_feb.onehourbase 
      AND diagnosismapping.dx_id in ('""" + diagnosis_ids + """')
      AND (problemlist.problemstatus = "Active" OR problemlist.NOTED_DATE >= sm_positive_delta_results_feb.onehourbase - INTERVAL 1825 day)
    GROUP BY sm_positive_delta_results_feb.pat_id,sm_positive_delta_results_feb.instance, sm_positive_delta_results_feb.pat_enc_csn_id
    """
    )
    
    print(risk_factor)
    df = df.join(tmp, ['pat_id', 'pat_enc_csn_id','instance'], how='left').fillna({risk_factor: 'no'})
  return df

# %%
df = add_risk_factors(df, rf2snomed)

# %%
df.createOrReplaceTempView('df_baseline')

# %%
COMOR = spark.sql("""
SELECT 
problemlist.pat_id, problemlist.instance,

CASE
WHEN lower(diagnosismapping.codes) like ("b20%") THEN 'AIDS'  
WHEN lower(diagnosismapping.codes) like ("b21%") THEN 'AIDS'
WHEN lower(diagnosismapping.codes) like ("b22%") THEN 'AIDS'
WHEN lower(diagnosismapping.codes) like ("b24%") THEN 'AIDS'

WHEN lower(diagnosismapping.codes) like ("c0_%") THEN 'Cancer'  
WHEN lower(diagnosismapping.codes) like ("c1_%") THEN 'Cancer'
WHEN lower(diagnosismapping.codes) like ("c21%") THEN 'Cancer'
WHEN lower(diagnosismapping.codes) like ("c22%") THEN 'Cancer'
WHEN lower(diagnosismapping.codes) like ("c23%") THEN 'Cancer'
WHEN lower(diagnosismapping.codes) like ("c24%") THEN 'Cancer'
WHEN lower(diagnosismapping.codes) like ("c25%") THEN 'Cancer'
WHEN lower(diagnosismapping.codes) like ("c26%") THEN 'Cancer'
WHEN lower(diagnosismapping.codes) like ("c30%") THEN 'Cancer'  
WHEN lower(diagnosismapping.codes) like ("c31%") THEN 'Cancer'
WHEN lower(diagnosismapping.codes) like ("c32%") THEN 'Cancer'
WHEN lower(diagnosismapping.codes) like ("c33%") THEN 'Cancer'
WHEN lower(diagnosismapping.codes) like ("c34%") THEN 'Cancer'
WHEN lower(diagnosismapping.codes) like ("c37%") THEN 'Cancer'
WHEN lower(diagnosismapping.codes) like ("c38%") THEN 'Cancer'
WHEN lower(diagnosismapping.codes) like ("c39%") THEN 'Cancer'
WHEN lower(diagnosismapping.codes) like ("c40%") THEN 'Cancer'  
WHEN lower(diagnosismapping.codes) like ("c41%") THEN 'Cancer'
WHEN lower(diagnosismapping.codes) like ("c43%") THEN 'Cancer'
WHEN lower(diagnosismapping.codes) like ("c45%") THEN 'Cancer'
WHEN lower(diagnosismapping.codes) like ("c46%") THEN 'Cancer'
WHEN lower(diagnosismapping.codes) like ("c47%") THEN 'Cancer'
WHEN lower(diagnosismapping.codes) like ("c48%") THEN 'Cancer'
WHEN lower(diagnosismapping.codes) like ("c49%") THEN 'Cancer'
WHEN lower(diagnosismapping.codes) like ("c50%") THEN 'Cancer'  
WHEN lower(diagnosismapping.codes) like ("c51%") THEN 'Cancer'
WHEN lower(diagnosismapping.codes) like ("c52%") THEN 'Cancer'
WHEN lower(diagnosismapping.codes) like ("c53%") THEN 'Cancer'
WHEN lower(diagnosismapping.codes) like ("c54%") THEN 'Cancer'
WHEN lower(diagnosismapping.codes) like ("c56%") THEN 'Cancer'
WHEN lower(diagnosismapping.codes) like ("c57%") THEN 'Cancer'
WHEN lower(diagnosismapping.codes) like ("c58%") THEN 'Cancer'
WHEN lower(diagnosismapping.codes) like ("c6_%") THEN 'Cancer'
WHEN lower(diagnosismapping.codes) like ("c70%") THEN 'Cancer'
WHEN lower(diagnosismapping.codes) like ("c71%") THEN 'Cancer'
WHEN lower(diagnosismapping.codes) like ("c72%") THEN 'Cancer'
WHEN lower(diagnosismapping.codes) like ("c73%") THEN 'Cancer'
WHEN lower(diagnosismapping.codes) like ("c74%") THEN 'Cancer'
WHEN lower(diagnosismapping.codes) like ("c75%") THEN 'Cancer'
WHEN lower(diagnosismapping.codes) like ("c76%") THEN 'Cancer'
WHEN lower(diagnosismapping.codes) like ("c81%") THEN 'Cancer'  
WHEN lower(diagnosismapping.codes) like ("c82%") THEN 'Cancer'
WHEN lower(diagnosismapping.codes) like ("c83%") THEN 'Cancer'
WHEN lower(diagnosismapping.codes) like ("c84%") THEN 'Cancer'
WHEN lower(diagnosismapping.codes) like ("c85%") THEN 'Cancer'
WHEN lower(diagnosismapping.codes) like ("c88%") THEN 'Cancer'
WHEN lower(diagnosismapping.codes) like ("c90%") THEN 'Cancer'
WHEN lower(diagnosismapping.codes) like ("c91%") THEN 'Cancer'
WHEN lower(diagnosismapping.codes) like ("c92%") THEN 'Cancer'
WHEN lower(diagnosismapping.codes) like ("c93%") THEN 'Cancer'
WHEN lower(diagnosismapping.codes) like ("c94%") THEN 'Cancer'
WHEN lower(diagnosismapping.codes) like ("c95%") THEN 'Cancer'
WHEN lower(diagnosismapping.codes) like ("c96%") THEN 'Cancer'
WHEN lower(diagnosismapping.codes) like ("c97%") THEN 'Cancer'

WHEN lower(diagnosismapping.codes) like ("c77%") THEN 'metastatic'  
WHEN lower(diagnosismapping.codes) like ("c78%") THEN 'metastatic'
WHEN lower(diagnosismapping.codes) like ("c79%") THEN 'metastatic'
WHEN lower(diagnosismapping.codes) like ("c80%") THEN 'metastatic'

WHEN lower(diagnosismapping.codes) like ("g45%") THEN 'CD'  
WHEN lower(diagnosismapping.codes) like ("g46%") THEN 'CD'
WHEN lower(diagnosismapping.codes) like ("h34%") THEN 'CD'
WHEN lower(diagnosismapping.codes) like ("i6_%") THEN 'CD'

WHEN lower(diagnosismapping.codes) like ("i27.8%") THEN 'CPD'  
WHEN lower(diagnosismapping.codes) like ("i27.9%") THEN 'CPD'
WHEN lower(diagnosismapping.codes) like ("j40%") THEN 'CPD'
WHEN lower(diagnosismapping.codes) like ("j41%") THEN 'CPD'
WHEN lower(diagnosismapping.codes) like ("j42%") THEN 'CPD'
WHEN lower(diagnosismapping.codes) like ("j43%") THEN 'CPD'
WHEN lower(diagnosismapping.codes) like ("j44%") THEN 'CPD'
WHEN lower(diagnosismapping.codes) like ("j45%") THEN 'CPD'
WHEN lower(diagnosismapping.codes) like ("j46%") THEN 'CPD'
WHEN lower(diagnosismapping.codes) like ("j47%") THEN 'CPD'
WHEN lower(diagnosismapping.codes) like ("j60%") THEN 'CPD'
WHEN lower(diagnosismapping.codes) like ("j61%") THEN 'CPD'
WHEN lower(diagnosismapping.codes) like ("j62%") THEN 'CPD'
WHEN lower(diagnosismapping.codes) like ("j63%") THEN 'CPD'
WHEN lower(diagnosismapping.codes) like ("j64%") THEN 'CPD'
WHEN lower(diagnosismapping.codes) like ("j65%") THEN 'CPD'
WHEN lower(diagnosismapping.codes) like ("j66%") THEN 'CPD'
WHEN lower(diagnosismapping.codes) like ("j67%") THEN 'CPD'
WHEN lower(diagnosismapping.codes) like ("j68.4%") THEN 'CPD'
WHEN lower(diagnosismapping.codes) like ("j70.1%") THEN 'CPD'
WHEN lower(diagnosismapping.codes) like ("j70.3%") THEN 'CPD'

WHEN lower(diagnosismapping.codes) like ("i09.9%") THEN 'CHF'  
WHEN lower(diagnosismapping.codes) like ("i11.0%") THEN 'CHF'
WHEN lower(diagnosismapping.codes) like ("i13.0%") THEN 'CHF'
WHEN lower(diagnosismapping.codes) like ("i13.2%") THEN 'CHF'
WHEN lower(diagnosismapping.codes) like ("i25.5%") THEN 'CHF'
WHEN lower(diagnosismapping.codes) like ("i42.0%") THEN 'CHF'
WHEN lower(diagnosismapping.codes) like ("i42.5%") THEN 'CHF'
WHEN lower(diagnosismapping.codes) like ("i42.6%") THEN 'CHF'
WHEN lower(diagnosismapping.codes) like ("i42.7%") THEN 'CHF'
WHEN lower(diagnosismapping.codes) like ("i42.8%") THEN 'CHF'
WHEN lower(diagnosismapping.codes) like ("i42.9%") THEN 'CHF'
WHEN lower(diagnosismapping.codes) like ("i43%") THEN 'CHF'
WHEN lower(diagnosismapping.codes) like ("i50%") THEN 'CHF'
WHEN lower(diagnosismapping.codes) like ("p29.0%") THEN 'CHF'

WHEN lower(diagnosismapping.codes) like ("f00%") THEN 'Dementia'  
WHEN lower(diagnosismapping.codes) like ("f01%") THEN 'Dementia'
WHEN lower(diagnosismapping.codes) like ("f02%") THEN 'Dementia'
WHEN lower(diagnosismapping.codes) like ("f03%") THEN 'Dementia'
WHEN lower(diagnosismapping.codes) like ("f05.1%") THEN 'Dementia'
WHEN lower(diagnosismapping.codes) like ("g30%") THEN 'Dementia'
WHEN lower(diagnosismapping.codes) like ("g31.1%") THEN 'Dementia'

WHEN lower(diagnosismapping.codes) like ("e10.0%") THEN 'Diabetes'  
WHEN lower(diagnosismapping.codes) like ("e10.1%") THEN 'Diabetes'
WHEN lower(diagnosismapping.codes) like ("e10.6%") THEN 'Diabetes'
WHEN lower(diagnosismapping.codes) like ("e10.8%") THEN 'Diabetes'
WHEN lower(diagnosismapping.codes) like ("e10.9%") THEN 'Diabetes'
WHEN lower(diagnosismapping.codes) like ("e11.0%") THEN 'Diabetes'
WHEN lower(diagnosismapping.codes) like ("e11.1%") THEN 'Diabetes'
WHEN lower(diagnosismapping.codes) like ("e11.6%") THEN 'Diabetes'  
WHEN lower(diagnosismapping.codes) like ("e11.8%") THEN 'Diabetes'
WHEN lower(diagnosismapping.codes) like ("e11.9%") THEN 'Diabetes'
WHEN lower(diagnosismapping.codes) like ("e12.0%") THEN 'Diabetes'
WHEN lower(diagnosismapping.codes) like ("e12.1%") THEN 'Diabetes'
WHEN lower(diagnosismapping.codes) like ("e12.6%") THEN 'Diabetes'
WHEN lower(diagnosismapping.codes) like ("e12.8%") THEN 'Diabetes'
WHEN lower(diagnosismapping.codes) like ("e12.9%") THEN 'Diabetes'  
WHEN lower(diagnosismapping.codes) like ("e13.0%") THEN 'Diabetes'
WHEN lower(diagnosismapping.codes) like ("e13.1%") THEN 'Diabetes'
WHEN lower(diagnosismapping.codes) like ("e13.6%") THEN 'Diabetes'
WHEN lower(diagnosismapping.codes) like ("e13.8%") THEN 'Diabetes'
WHEN lower(diagnosismapping.codes) like ("e13.9%") THEN 'Diabetes'
WHEN lower(diagnosismapping.codes) like ("e14.0%") THEN 'Diabetes'
WHEN lower(diagnosismapping.codes) like ("e14.1%") THEN 'Diabetes'  
WHEN lower(diagnosismapping.codes) like ("e14.6%") THEN 'Diabetes'
WHEN lower(diagnosismapping.codes) like ("e14.8%") THEN 'Diabetes'
WHEN lower(diagnosismapping.codes) like ("e14.9%") THEN 'Diabetes'

WHEN lower(diagnosismapping.codes) like ("e10.2%") THEN 'Diabetes_W'
WHEN lower(diagnosismapping.codes) like ("e10.3%") THEN 'Diabetes_W'
WHEN lower(diagnosismapping.codes) like ("e10.4%") THEN 'Diabetes_W'
WHEN lower(diagnosismapping.codes) like ("e10.5%") THEN 'Diabetes_W'  
WHEN lower(diagnosismapping.codes) like ("e10.7%") THEN 'Diabetes_W'
WHEN lower(diagnosismapping.codes) like ("e11.2%") THEN 'Diabetes_W'
WHEN lower(diagnosismapping.codes) like ("e11.3%") THEN 'Diabetes_W'
WHEN lower(diagnosismapping.codes) like ("e11.4%") THEN 'Diabetes_W'
WHEN lower(diagnosismapping.codes) like ("e11.5%") THEN 'Diabetes_W'
WHEN lower(diagnosismapping.codes) like ("e11.7%") THEN 'Diabetes_W'
WHEN lower(diagnosismapping.codes) like ("e12.2%") THEN 'Diabetes_W'
WHEN lower(diagnosismapping.codes) like ("e12.3%") THEN 'Diabetes_W'
WHEN lower(diagnosismapping.codes) like ("e12.4%") THEN 'Diabetes_W'
WHEN lower(diagnosismapping.codes) like ("e12.5%") THEN 'Diabetes_W'  
WHEN lower(diagnosismapping.codes) like ("e12.7%") THEN 'Diabetes_W'
WHEN lower(diagnosismapping.codes) like ("e13.2%") THEN 'Diabetes_W'
WHEN lower(diagnosismapping.codes) like ("e13.3%") THEN 'Diabetes_W'
WHEN lower(diagnosismapping.codes) like ("e13.4%") THEN 'Diabetes_W'
WHEN lower(diagnosismapping.codes) like ("e13.5%") THEN 'Diabetes_W'
WHEN lower(diagnosismapping.codes) like ("e13.7%") THEN 'Diabetes_W'
WHEN lower(diagnosismapping.codes) like ("e14.2%") THEN 'Diabetes_W'
WHEN lower(diagnosismapping.codes) like ("e14.3%") THEN 'Diabetes_W'
WHEN lower(diagnosismapping.codes) like ("e14.4%") THEN 'Diabetes_W'
WHEN lower(diagnosismapping.codes) like ("e14.5%") THEN 'Diabetes_W'
WHEN lower(diagnosismapping.codes) like ("e14.7%") THEN 'Diabetes_W'

WHEN lower(diagnosismapping.codes) like ("b18%") THEN 'LD_M'
WHEN lower(diagnosismapping.codes) like ("k70.0%") THEN 'LD_M'
WHEN lower(diagnosismapping.codes) like ("k70.1%") THEN 'LD_M'
WHEN lower(diagnosismapping.codes) like ("k70.2%") THEN 'LD_M'  
WHEN lower(diagnosismapping.codes) like ("k70.3%") THEN 'LD_M'
WHEN lower(diagnosismapping.codes) like ("k70.9%") THEN 'LD_M'
WHEN lower(diagnosismapping.codes) like ("k71.3%") THEN 'LD_M'
WHEN lower(diagnosismapping.codes) like ("k71.4%") THEN 'LD_M'
WHEN lower(diagnosismapping.codes) like ("k71.5%") THEN 'LD_M'
WHEN lower(diagnosismapping.codes) like ("k71.7%") THEN 'LD_M'
WHEN lower(diagnosismapping.codes) like ("k73%") THEN 'LD_M'
WHEN lower(diagnosismapping.codes) like ("k74%") THEN 'LD_M'
WHEN lower(diagnosismapping.codes) like ("k76.0%") THEN 'LD_M'
WHEN lower(diagnosismapping.codes) like ("k76.2%") THEN 'LD_M'  
WHEN lower(diagnosismapping.codes) like ("k76.3%") THEN 'LD_M'
WHEN lower(diagnosismapping.codes) like ("k76.4%") THEN 'LD_M'
WHEN lower(diagnosismapping.codes) like ("k76.8%") THEN 'LD_M'
WHEN lower(diagnosismapping.codes) like ("k76.9%") THEN 'LD_M'
WHEN lower(diagnosismapping.codes) like ("z94.4%") THEN 'LD_M'

WHEN lower(diagnosismapping.codes) like ("i85.0%") THEN 'LD_S'
WHEN lower(diagnosismapping.codes) like ("i85.9%") THEN 'LD_S'
WHEN lower(diagnosismapping.codes) like ("i86.4%") THEN 'LD_S'
WHEN lower(diagnosismapping.codes) like ("i98.2%") THEN 'LD_S'  
WHEN lower(diagnosismapping.codes) like ("k70.4%") THEN 'LD_S'
WHEN lower(diagnosismapping.codes) like ("k71.1%") THEN 'LD_S'
WHEN lower(diagnosismapping.codes) like ("k72.1%") THEN 'LD_S'
WHEN lower(diagnosismapping.codes) like ("k72.9%") THEN 'LD_S'
WHEN lower(diagnosismapping.codes) like ("k76.5%") THEN 'LD_S'
WHEN lower(diagnosismapping.codes) like ("k76.6%") THEN 'LD_S'
WHEN lower(diagnosismapping.codes) like ("k76.7%") THEN 'LD_S'

WHEN lower(diagnosismapping.codes) like ("i21%") THEN 'MI'
WHEN lower(diagnosismapping.codes) like ("i22%") THEN 'MI'
WHEN lower(diagnosismapping.codes) like ("i25.2%") THEN 'MI'
WHEN lower(diagnosismapping.codes) like ("i09.9%") THEN 'MI'  
WHEN lower(diagnosismapping.codes) like ("i11.0%") THEN 'MI'
WHEN lower(diagnosismapping.codes) like ("i13.0%") THEN 'MI'
WHEN lower(diagnosismapping.codes) like ("i13.2%") THEN 'MI'
WHEN lower(diagnosismapping.codes) like ("i25.5%") THEN 'MI'
WHEN lower(diagnosismapping.codes) like ("i42.0%") THEN 'MI'
WHEN lower(diagnosismapping.codes) like ("i42.5%") THEN 'MI'
WHEN lower(diagnosismapping.codes) like ("i42.6%") THEN 'MI'
WHEN lower(diagnosismapping.codes) like ("i42.7%") THEN 'MI'
WHEN lower(diagnosismapping.codes) like ("i42.8%") THEN 'MI'
WHEN lower(diagnosismapping.codes) like ("i42.9%") THEN 'MI'
WHEN lower(diagnosismapping.codes) like ("i43%") THEN 'MI'
WHEN lower(diagnosismapping.codes) like ("i50%") THEN 'MI'
WHEN lower(diagnosismapping.codes) like ("p29.0%") THEN 'MI'

WHEN lower(diagnosismapping.codes) like ("k25%") THEN 'PUD'
WHEN lower(diagnosismapping.codes) like ("k26%") THEN 'PUD'
WHEN lower(diagnosismapping.codes) like ("k27%") THEN 'PUD'
WHEN lower(diagnosismapping.codes) like ("k28%") THEN 'PUD'  

WHEN lower(diagnosismapping.codes) like ("i70%") THEN 'PVD'
WHEN lower(diagnosismapping.codes) like ("i71%") THEN 'PVD'
WHEN lower(diagnosismapping.codes) like ("i73.1%") THEN 'PVD'
WHEN lower(diagnosismapping.codes) like ("i73.8%") THEN 'PVD'
WHEN lower(diagnosismapping.codes) like ("i73.9%") THEN 'PVD'
WHEN lower(diagnosismapping.codes) like ("i77.1%") THEN 'PVD'
WHEN lower(diagnosismapping.codes) like ("i79.0%") THEN 'PVD'
WHEN lower(diagnosismapping.codes) like ("i79.2%") THEN 'PVD'
WHEN lower(diagnosismapping.codes) like ("k55.1%") THEN 'PVD'
WHEN lower(diagnosismapping.codes) like ("k55.8%") THEN 'PVD'
WHEN lower(diagnosismapping.codes) like ("k55.9%") THEN 'PVD'
WHEN lower(diagnosismapping.codes) like ("z95.8%") THEN 'PVD'
WHEN lower(diagnosismapping.codes) like ("z95.9%") THEN 'PVD'

WHEN lower(diagnosismapping.codes) like ("g04.1%") THEN 'Plegia'
WHEN lower(diagnosismapping.codes) like ("g11.4%") THEN 'Plegia'
WHEN lower(diagnosismapping.codes) like ("g80.1%") THEN 'Plegia'
WHEN lower(diagnosismapping.codes) like ("g80.2%") THEN 'Plegia'
WHEN lower(diagnosismapping.codes) like ("g81%") THEN 'Plegia'
WHEN lower(diagnosismapping.codes) like ("g82%") THEN 'Plegia'
WHEN lower(diagnosismapping.codes) like ("g83.0%") THEN 'Plegia'
WHEN lower(diagnosismapping.codes) like ("g83.1%") THEN 'Plegia'
WHEN lower(diagnosismapping.codes) like ("g83.2%") THEN 'Plegia'
WHEN lower(diagnosismapping.codes) like ("g83.3%") THEN 'Plegia'
WHEN lower(diagnosismapping.codes) like ("g83.4%") THEN 'Plegia'
WHEN lower(diagnosismapping.codes) like ("g83.9%") THEN 'Plegia'

WHEN lower(diagnosismapping.codes) like ("i12.0%") THEN 'RenalD'
WHEN lower(diagnosismapping.codes) like ("i13.1%") THEN 'RenalD'
WHEN lower(diagnosismapping.codes) like ("n03.2%") THEN 'RenalD'
WHEN lower(diagnosismapping.codes) like ("n03.3%") THEN 'RenalD'
WHEN lower(diagnosismapping.codes) like ("n03.4%") THEN 'RenalD'
WHEN lower(diagnosismapping.codes) like ("n03.5%") THEN 'RenalD'
WHEN lower(diagnosismapping.codes) like ("n03.6%") THEN 'RenalD'
WHEN lower(diagnosismapping.codes) like ("n03.7%") THEN 'RenalD'
WHEN lower(diagnosismapping.codes) like ("n05.2%") THEN 'RenalD'
WHEN lower(diagnosismapping.codes) like ("n05.3%") THEN 'RenalD'
WHEN lower(diagnosismapping.codes) like ("n05.4%") THEN 'RenalD'
WHEN lower(diagnosismapping.codes) like ("n05.5%") THEN 'RenalD'
WHEN lower(diagnosismapping.codes) like ("n05.6%") THEN 'RenalD'
WHEN lower(diagnosismapping.codes) like ("n05.7%") THEN 'RenalD'
WHEN lower(diagnosismapping.codes) like ("n18%") THEN 'RenalD'
WHEN lower(diagnosismapping.codes) like ("n19%") THEN 'RenalD'
WHEN lower(diagnosismapping.codes) like ("n25.0%") THEN 'RenalD'
WHEN lower(diagnosismapping.codes) like ("z49.0%") THEN 'RenalD'
WHEN lower(diagnosismapping.codes) like ("z49.1%") THEN 'RenalD'
WHEN lower(diagnosismapping.codes) like ("z49.2%") THEN 'RenalD'
WHEN lower(diagnosismapping.codes) like ("z94.0%") THEN 'RenalD'
WHEN lower(diagnosismapping.codes) like ("z99.2%") THEN 'RenalD'

WHEN lower(diagnosismapping.codes) like ("m05%") THEN 'Rheumatic'
WHEN lower(diagnosismapping.codes) like ("m06%") THEN 'Rheumatic'
WHEN lower(diagnosismapping.codes) like ("m31.5%") THEN 'Rheumatic'
WHEN lower(diagnosismapping.codes) like ("m32%") THEN 'Rheumatic'
WHEN lower(diagnosismapping.codes) like ("m33%") THEN 'Rheumatic'
WHEN lower(diagnosismapping.codes) like ("m34%") THEN 'Rheumatic'
WHEN lower(diagnosismapping.codes) like ("m35.1%") THEN 'Rheumatic'
WHEN lower(diagnosismapping.codes) like ("m35.3%") THEN 'Rheumatic'
WHEN lower(diagnosismapping.codes) like ("m36.0%") THEN 'Rheumatic'

Else 'Unknown'
END as Comorbidities
FROM df_baseline
INNER JOIN rdp_phi.problemlist ON df_baseline.pat_id = problemlist.pat_id AND df_baseline.instance = problemlist.instance
INNER JOIN rdp_phi.externalconceptmapping ON rdp_phi.problemlist.dx_id = rdp_phi.externalconceptmapping.value
INNER JOIN rdp_phi.diagnosismapping ON rdp_phi.problemlist.dx_id = rdp_phi.diagnosismapping.dx_id
WHERE problemlist.noted_date <= df_baseline.onehourbase
GROUP BY problemlist.pat_id,codes, problemlist.instance""")

COMOR = COMOR.dropDuplicates()
COMOR = COMOR.filter(COMOR.Comorbidities != "Unknown")

# %%
from pyspark.sql.window import Window
### This cell is to choose the highest rank among similar comorbidities such as cancer and metastatic
w = Window.partitionBy(['pat_id','instance']).rowsBetween(Window.unboundedPreceding,Window.unboundedFollowing)

COMOR1 = COMOR.withColumn("All_COMO", (collect_list(col("Comorbidities")).over(w)))

COMOR1 = COMOR1.withColumn("Mutual", 
                       when((array_contains("All_COMO","Diabetes")) & (array_contains("All_COMO","Diabetes_W")), "Diabetes")
                       .when((array_contains("All_COMO","Cancer"))  & (array_contains("All_COMO","metastatic")), "Cancer")
                       .when((array_contains("All_COMO","LD_M")) & (array_contains("All_COMO","LD_S")), "LD_M")
                       .otherwise('ok'))

COMOR1 = COMOR1.filter(COMOR1.Mutual != 'ok')

COMOR1 = COMOR1.drop(COMOR1.All_COMO).drop(COMOR1.Comorbidities)

COMOR1 = COMOR1.withColumnRenamed("Mutual","Comorbidities")

COMOR = COMOR.join(COMOR1,["pat_id","instance","Comorbidities"],'leftanti') #### ATTENTION IT IS LEFTANTI

COMOR = COMOR.dropDuplicates()

# %%
COMOR = COMOR.withColumn("scores", 
                         when(COMOR.Comorbidities == "AIDS", 6)
                        .when(COMOR.Comorbidities == "Cancer", 2)
                        .when(COMOR.Comorbidities == "metastatic", 6)
                        .when(COMOR.Comorbidities == "CD", 1)
                        .when(COMOR.Comorbidities == "CPD", 1)
                        .when(COMOR.Comorbidities == "CHF", 1)
                        .when(COMOR.Comorbidities == "Dementia", 1)
                        .when(COMOR.Comorbidities == "Diabetes", 1)
                        .when(COMOR.Comorbidities == "Diabetes_W", 2)
                        .when(COMOR.Comorbidities == "LD_M", 1)
                        .when(COMOR.Comorbidities == "LD_S", 3)
                        .when(COMOR.Comorbidities == "MI", 1)
                        .when(COMOR.Comorbidities == "PUD", 1)
                        .when(COMOR.Comorbidities == "PVD", 1)
                        .when(COMOR.Comorbidities == "Plegia", 2)
                        .when(COMOR.Comorbidities == "RenalD", 2)
                        .when(COMOR.Comorbidities == "Rheumatic", 1))

w = Window.partitionBy(['pat_id','instance']).rowsBetween(Window.unboundedPreceding,Window.unboundedFollowing)

COMOR = COMOR.withColumn("CCI", sum('scores').over(w))

COMOR = COMOR.drop('Comorbidities').drop('scores')
COMOR = COMOR.dropDuplicates()

# %%
df = df.join(COMOR,["pat_id","instance"],'left')
df = df.withColumn('CCI',when(df.CCI.isNull(),0).otherwise(df.CCI))

# %% [markdown]
# ### 3. Saving the updated dataframe

# %%
# %sql
DROP TABLE rdp_phi_sandbox.sm_patt_delta_baseline_feb;

# %%
table_name = 'rdp_phi_sandbox.sm_patt_delta_baseline_feb'
df.write.saveAsTable(table_name)

# %%
# %sql
REFRESH table_name;
SELECT * FROM rdp_phi_sandbox.sm_patt_delta_baseline_feb;
